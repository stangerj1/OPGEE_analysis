# %%
# !pip install cartopy

# %%
import pandas as pd
import numpy as np

# plotting not yet supported
from cartopy import crs as ccrs, feature as cfeature 
import cartopy.io.shapereader as shpreader
import matplotlib.pyplot as plt

# %%
import pycountry    # finding country names
import difflib      # quanitfying string differences

# %%
# Function to create new columns for difference, percent change, and percentage makeup
def add_difference_and_percent(df, col1, col2):
    # Calculate the difference
    diff_col_name = f'{col1}_minus_{col2}'
    df[diff_col_name] = df[col1] - df[col2]
    
    # Calculate the percent change
    pct_change_col_name = f'{col1}_pct_change_{col2}'
    df[pct_change_col_name] = (df[col1] - df[col2]) / df[col2] * 100


    # Calculate the percent of previous
    # pct_prev_col_name = f'{col1}_pct_previous_{col2}'
    # df[pct_prev_col_name] = df[col1] / df[col2] * 100
    
    return df

# %%
volumes = pd.read_csv("./data/country_percent_scale_080124.csv")    # read in volumes of production in 2023
volumes
# Out:
#    iso3_country  actual_production_boed  expected_production_boed  \
# 0           AGO            1.196436e+06              1.196436e+06
# 1           ALB            1.121734e+04              1.121734e+04
# 2           ARE            5.519692e+06              5.519692e+06
# 3           ARG            1.355164e+06              1.355164e+06
# 4           AUS            2.124336e+06              2.124336e+06
# ..          ...                     ...                       ...
# 80          USA            2.973635e+07              3.353577e+07
# 81          UZB            8.005956e+05              8.005956e+05
# 82          VEN            8.005084e+05              8.005084e+05
# 83          VNM            2.840607e+05              2.840607e+05
# 84          YEM            7.721110e+04              7.721110e+04
#
#     percent_production_modeled
# 0                     1.000000
# 1                     1.000000
# 2                     1.000000
# 3                     1.000000
# 4                     1.000000
# ..                         ...
# 80                    0.886705
# 81                    1.000000
# 82                    1.000000
# 83                    1.000000
# 84                    1.000000
#
# [85 rows x 4 columns]

# %%
new_prod_in = pd.read_csv("./data/country-climate-trace_oil-and-gas-production_100824.csv")
new_trans_in = pd.read_csv("./data/country-climate-trace_oil-and-gas-transport_100824.csv")

# trace22_in = pd.read_csv("./data/trace22.csv") 
trace22_in = pd.read_csv("./data/oil-and-gas-production-and-transport_country_emissions.csv")

# %%
new_prod_in.dropna(subset=['start_date'], inplace=True)
new_prod = new_prod_in[
    new_prod_in['start_date'].str.contains('2023')
]
new_prod = new_prod[
    new_prod['end_date'].str.contains('2023')
]

new_trans_in.dropna(subset=['start_date'], inplace=True)
new_trans = new_trans_in[
    new_trans_in['start_date'].str.contains('2023')
]
new_trans = new_trans[
    new_trans['end_date'].str.contains('2023')
]

# %%
# country aggregated former run


trace22 = trace22_in[['iso3_country','end_time','gas','emissions_quantity']]            # restrict to only relevant columns
trace22 = trace22[trace22['end_time'].str.contains('2022')].drop(columns=['end_time'])  # keep only items that are from 2022 run and drop time
trace22 = trace22[trace22['gas'].isin(['co2','ch4'])]                                   # restrict to only carbon dioxide and methane

# pivot table and reset index to mimic other format
trace22 = trace22.pivot(                                                                
    index='iso3_country', columns='gas', values='emissions_quantity'
).reset_index()

# give column names for the gases
trace22.columns.name = None                                                         
trace22 = trace22.rename(columns={
    'co2': 'CO2_trace22_total',
    'ch4': 'CH4_trace22_total'
})

trace22 = trace22.replace(0,np.nan)

# %%
new_prod.set_index('iso3_country', inplace=True)
new_trans.set_index('iso3_country', inplace=True)
trace22.set_index('iso3_country', inplace=True)

# Join dataframes
joined = new_prod.join(
    new_trans, how='outer',
    lsuffix='_prod',rsuffix='_trans').join(
        trace22, how='outer')

joined.reset_index(inplace=True)

# %%
joined
# Out:
#     iso3_country start_date_prod end_date_prod  CO2_emissions_tonnes_prod  \
# 0            ABW      2023-01-01    2023-12-31                        NaN
# 1            AFG      2023-01-01    2023-12-31               7.180143e+04
# 2            AGO      2023-01-01    2023-12-31               1.343289e+07
# 3            AIA      2023-01-01    2023-12-31                        NaN
# 4            ALA      2023-01-01    2023-12-31                        NaN
# ..           ...             ...           ...                        ...
# 246          XKX      2023-01-01    2023-12-31                        NaN
# 247          YEM      2023-01-01    2023-12-31               7.963005e+05
# 248          ZAF      2023-01-01    2023-12-31                        NaN
# 249          ZMB      2023-01-01    2023-12-31                        NaN
# 250          ZWE      2023-01-01    2023-12-31                        NaN
#
#      CH4_emissions_tonnes_prod  N2O_emissions_tonnes_prod  \
# 0                          NaN                        NaN
# 1                  2685.643328                        0.0
# 2                568004.061806                        0.0
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 246                        NaN                        NaN
# 247               29784.631029                        0.0
# 248                        NaN                        NaN
# 249                        NaN                        NaN
# 250                        NaN                        NaN
#
#      total_CO2e_100yrGWP_prod  total_CO2e_20yrGWP_prod start_date_trans  \
# 0                         NaN                      NaN       2023-01-01
# 1                1.518336e+05             2.933670e+05       2023-01-01
# 2                3.035941e+07             6.029323e+07       2023-01-01
# 3                         NaN                      NaN       2023-01-01
# 4                         NaN                      NaN       2023-01-01
# ..                        ...                      ...              ...
# 246                       NaN                      NaN       2023-01-01
# 247              1.683883e+06             3.253533e+06       2023-01-01
# 248                       NaN                      NaN       2023-01-01
# 249                       NaN                      NaN       2023-01-01
# 250                       NaN                      NaN       2023-01-01
#
#     end_date_trans  CO2_emissions_tonnes_trans  CH4_emissions_tonnes_trans  \
# 0       2023-12-31                         NaN                         NaN
# 1       2023-12-31                6.504703e+04                  483.921676
# 2       2023-12-31                8.028758e+06                 1252.094929
# 3       2023-12-31                         NaN                         NaN
# 4       2023-12-31                         NaN                         NaN
# ..             ...                         ...                         ...
# 246     2023-12-31                         NaN                         NaN
# 247     2023-12-31                7.213920e+05                 5366.843915
# 248     2023-12-31                         NaN                         NaN
# 249     2023-12-31                         NaN                         NaN
# 250     2023-12-31                         NaN                         NaN
#
#      N2O_emissions_tonnes_trans  total_CO2e_100yrGWP_trans  \
# 0                           NaN                        NaN
# 1                           0.0               7.946789e+04
# 2                           0.0               8.066071e+06
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 246                         NaN                        NaN
# 247                         0.0               8.813240e+05
# 248                         NaN                        NaN
# 249                         NaN                        NaN
# 250                         NaN                        NaN
#
#      total_CO2e_20yrGWP_trans  CH4_trace22_total  CO2_trace22_total
# 0                         NaN                NaN                NaN
# 1                1.049706e+05                NaN                NaN
# 2                8.132056e+06      514227.525006       1.551758e+07
# 3                         NaN                NaN                NaN
# 4                         NaN                NaN                NaN
# ..                        ...                ...                ...
# 246                       NaN                NaN                NaN
# 247              1.164157e+06      163956.998302       3.894952e+06
# 248                       NaN        2878.461559       1.172470e+05
# 249                       NaN                NaN                NaN
# 250                       NaN                NaN                NaN
#
# [251 rows x 17 columns]

# %%
joined['CO2_trace_new_total'] = joined['CO2_emissions_tonnes_prod'] + joined['CO2_emissions_tonnes_trans']
joined['CH4_trace_new_total'] = joined['CH4_emissions_tonnes_prod'] + joined['CH4_emissions_tonnes_trans']

merged = joined[
    ['iso3_country',
     'CO2_emissions_tonnes_prod', 'CO2_emissions_tonnes_trans',
     'CH4_emissions_tonnes_prod', 'CH4_emissions_tonnes_trans',
     'CO2_trace_new_total', 'CH4_trace_new_total',
     'CO2_trace22_total', 'CH4_trace22_total']
]

world_row = pd.DataFrame([merged.sum()],columns=merged.columns)
world_row['iso3_country'] = 'World'
merged = pd.concat([merged,world_row], ignore_index=True)

# %%
merged
# Out:
#     iso3_country  CO2_emissions_tonnes_prod  CO2_emissions_tonnes_trans  \
# 0            ABW                        NaN                         NaN
# 1            AFG               7.180143e+04                6.504703e+04
# 2            AGO               1.343289e+07                8.028758e+06
# 3            AIA                        NaN                         NaN
# 4            ALA                        NaN                         NaN
# ..           ...                        ...                         ...
# 247          YEM               7.963005e+05                7.213920e+05
# 248          ZAF                        NaN                         NaN
# 249          ZMB                        NaN                         NaN
# 250          ZWE                        NaN                         NaN
# 251        World               2.258459e+09                1.575755e+09
#
#      CH4_emissions_tonnes_prod  CH4_emissions_tonnes_trans  \
# 0                          NaN                         NaN
# 1                 2.685643e+03                4.839217e+02
# 2                 5.680041e+05                1.252095e+03
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 247               2.978463e+04                5.366844e+03
# 248                        NaN                         NaN
# 249                        NaN                         NaN
# 250                        NaN                         NaN
# 251               5.684872e+07                1.308652e+07
#
#      CO2_trace_new_total  CH4_trace_new_total  CO2_trace22_total  \
# 0                    NaN                  NaN                NaN
# 1           1.368485e+05         3.169565e+03                NaN
# 2           2.146165e+07         5.692562e+05       1.551758e+07
# 3                    NaN                  NaN                NaN
# 4                    NaN                  NaN                NaN
# ..                   ...                  ...                ...
# 247         1.517693e+06         3.515147e+04       3.894952e+06
# 248                  NaN                  NaN       1.172470e+05
# 249                  NaN                  NaN                NaN
# 250                  NaN                  NaN                NaN
# 251         3.834215e+09         6.993524e+07       3.793789e+09
#
#      CH4_trace22_total
# 0                  NaN
# 1                  NaN
# 2         5.142275e+05
# 3                  NaN
# 4                  NaN
# ..                 ...
# 247       1.639570e+05
# 248       2.878462e+03
# 249                NaN
# 250                NaN
# 251       6.938903e+07
#
# [252 rows x 9 columns]

# %%
merged = add_difference_and_percent(merged,'CO2_trace_new_total','CO2_trace22_total')       # adding columns for production diff in carbon dioxide
merged = add_difference_and_percent(merged,'CH4_trace_new_total','CH4_trace22_total')       # adding columns for production diff in methane

# %%
merged.to_csv('./data/new_method_&_v3_100924.csv',index=False) # write csv of this
